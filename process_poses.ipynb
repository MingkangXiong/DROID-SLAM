# %%
import numpy as np

# %%
poses = np.load("/home/mkxiong/Documents/projects/DROID-SLAM/reconstructions/agv_new/poses.npy")
times = np.load("/home/mkxiong/Documents/projects/DROID-SLAM/reconstructions/agv_new/tstamps.npy")

# %%
print(poses)
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  1.00000000e+00]
#  [-2.54267972e-04  9.30168200e-03 -4.18367758e-02  1.57643967e-06
#   -3.96646465e-06 -2.56719912e-04  1.00000000e+00]
#  [-6.66723936e-04  1.89290438e-02 -8.66718665e-02 -7.65971999e-05
#    1.66252739e-05 -2.22449438e-04  1.00000000e+00]
#  [-1.10146031e-03  2.74109785e-02 -1.28240377e-01 -1.09425702e-04
#    2.06740820e-04  2.74394930e-04  9.99999940e-01]
#  [-2.04792619e-02  3.61852609e-02 -1.66705847e-01 -2.69221346e-04
#    9.48011893e-06  1.06452913e-04  1.00000012e+00]
#  [-6.54783845e-02  3.65268588e-02 -1.65327549e-01 -1.56624781e-04
#    4.38806183e-06  7.80139817e-05  9.99999821e-01]
#  [-1.15782849e-01  3.72252800e-02 -1.66393563e-01 -1.77443377e-04
#    5.04716118e-05  7.95502710e-05  9.99999464e-01]
#  [-2.13099211e-01  3.74053977e-02 -1.60164103e-01 -5.18846682e-05
#   -3.20309569e-04 -5.26591612e-05  9.99999583e-01]
# ...

# %%
print(times)
# Out:
# [   0.   34.   46.   57.   69.   72.   75.   78.   84.   90.   96.  102.
#   107.  112.  117.  123.  129.  135.  140.  159.  193.  201.  213.  222.
#   231.  240.  249.  255.  272.  317.  361.  445.  453.  462.  471.  480.
#   489.  498.  518.  584.  593.  602.  611.  620.  629.  638.  647.  656.
#   833.  841.  850.  859.  868.  877.  886.  893.  899.  905.  910.  993.
#  1015. 1023. 1031. 1046. 1059. 1068. 1258. 1267. 1285. 1300. 1310. 1321.
#  1479. 1521. 1550. 1565. 1734. 1771. 1777. 1783. 1789. 1795. 1801. 1807.
#  1813. 1819. 1825. 1831. 1837. 1845. 1885. 1891. 1897. 1903. 1909. 1915.
#  1921. 1927. 1933. 1939. 1945. 1951. 1957. 1972.]

# %%
poses_with_times = np.insert(poses, 0, times, axis=1)
print(poses_with_times.shape)
# Out:
# (104, 8)

# %%
np.savetxt('/home/mkxiong/Documents/projects/DROID-SLAM/reconstructions/agv_new/poses_with_times.txt', poses_with_times)

# %%
#evo_traj tum poses_with_times.txt --save_as_kitti
