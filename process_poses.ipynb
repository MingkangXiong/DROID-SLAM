# %%
import numpy as np

# %%
poses = np.load("/home/mkxiong/Documents/projects/DROID-SLAM/reconstructions/rgbd_dataset_freiburg3_cabinet/poses.npy")
times = np.load("/home/mkxiong/Documents/projects/DROID-SLAM/reconstructions/rgbd_dataset_freiburg3_cabinet/tstamps.npy")

# %%
print(poses)
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  1.00000000e+00]
#  [ 1.82678327e-02 -3.26752616e-03  9.52605531e-03 -8.67496524e-03
#   -5.95247000e-03 -1.18825547e-02  9.99874294e-01]
#  [ 7.60597959e-02 -5.74112451e-03  9.59553476e-03 -9.82019957e-03
#   -1.99149102e-02 -2.50454731e-02  9.99439836e-01]
#  [ 1.17810532e-01  5.32269711e-03 -5.37710078e-03 -1.15623912e-02
#   -3.55831236e-02 -4.00501117e-02  9.98497188e-01]
#  [ 1.46183059e-01  1.04891537e-02 -1.05383359e-02 -1.53341889e-02
#   -4.35166433e-02 -4.93849851e-02  9.97713566e-01]
#  [ 2.00527653e-01  2.49117892e-02 -2.18365006e-02 -9.64992587e-03
#   -5.94031960e-02 -6.13303259e-02  9.96301591e-01]
#  [ 2.54392892e-01  2.95340642e-02 -2.70065255e-02 -1.07928002e-02
#   -7.29424357e-02 -7.17395321e-02  9.94694173e-01]
#  [ 3.88418317e-01  4.57085744e-02 -1.04344906e-02 -7.51168653e-03
#   -1.16506331e-01 -8.89316425e-02  9.89172578e-01]
# ...

# %%
print(times)
# Out:
# [  0.   1.   4.   6.   7.   9.  11.  15.  19.  23.  28.  33.  37.  42.
#   46.  53.  57.  61.  67.  70.  75.  80.  87.  91.  96. 103. 107. 114.
#  119. 126. 129. 135. 148. 155. 161. 171. 176. 186. 191. 197. 204. 209.
#  218. 222. 229. 234. 241. 247. 253. 259. 265. 274. 288. 293. 302. 309.
#  317. 327. 339. 347. 355. 364. 370.]

# %%
poses_with_times = np.insert(poses, 0, times, axis=1)
print(poses_with_times.shape)
# Out:
# (63, 8)

# %%
np.savetxt('/home/mkxiong/Documents/projects/DROID-SLAM/reconstructions/rgbd_dataset_freiburg3_cabinet/poses_with_times.txt', poses_with_times)
